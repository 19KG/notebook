# %%
import pandas as pd
import numpy as np

# %%
movie_counter = {}
with open('../movie_data/doulist_0804_09.json') as fopen:
    for line in fopen:
        doulist_dict = json.loads(line.strip())
        for movie_name in doulist_dict['movie_names']:
            movie_name = movie_name.encode('utf8')
            if movie_name not in movie_counter:
                movie_counter[movie_name] = 0
            movie_counter[movie_name] += 1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-648833ebcbc9> in <module>()
#       1 movie_freq = filter(lambda _:_[1] >= min_word_freq, movie_counter.items())
# ----> 2 movie_counter_sorted = sorted(movie_freq, key=lambda x: (-x[1], x[0]))
#       3 movies, _ = list(zip(*movie_counter_sorted))
#       4 movie_name_id_dict = dict(zip(movies, xrange(len(movies))))
#       5 movie_name_id_dict['<unk>'] = len(movies)
#
# <ipython-input-7-648833ebcbc9> in <lambda>(_)
# ----> 1 movie_freq = filter(lambda _:_[1] >= min_word_freq, movie_counter.items())
#       2 movie_counter_sorted = sorted(movie_freq, key=lambda x: (-x[1], x[0]))
#       3 movies, _ = list(zip(*movie_counter_sorted))
#       4 movie_name_id_dict = dict(zip(movies, xrange(len(movies))))
#       5 movie_name_id_dict['<unk>'] = len(movies)
#
# NameError: name 'min_word_freq' is not defined
