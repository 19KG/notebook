# %%
import gc
import time
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from pandas import DataFrame as DF

usermovie = pd.read_csv('/data/data/delete_final_data.txt',sep=',')
movie_head = pd.read_csv('/data/data/final_movie_head.txt',sep=',')
movie=pd.read_csv('/data/data/Movie.txt',sep='\t')
movietxt_head=pd.read_csv('/data/data/movietxt_head.txt')

# %%
loan_inner=pd.merge(usermovie,movie_head,how='inner')

# %%
m_h_inner=pd.merge(movie,movie_head,how='inner')
#m_h_inner.to_csv('/data/data/movietxt_head.txt')

# %%
m_u_inner=pd.merge(m_h_inner,usermovie,how='inner')

# %%
m_u_inner
# Out:
#               mid                           name  \
# 0        10574622                        人再囧途之泰囧
# 1        10574622                        人再囧途之泰囧
# 2        10574622                        人再囧途之泰囧
# 3        10574622                        人再囧途之泰囧
# 4        10574622                        人再囧途之泰囧
# 5        10574622                        人再囧途之泰囧
# 6        10574622                        人再囧途之泰囧
# 7        10574622                        人再囧途之泰囧
# 8        10574622                        人再囧途之泰囧
# 9        10574622                        人再囧途之泰囧
# 10       10574622                        人再囧途之泰囧
# 11       10574622                        人再囧途之泰囧
# 12       10574622                        人再囧途之泰囧
# 13       10574622                        人再囧途之泰囧
# 14       10574622                        人再囧途之泰囧
# 15       10574622                        人再囧途之泰囧
# 16       10574622                        人再囧途之泰囧
# 17       10574622                        人再囧途之泰囧
# ...
