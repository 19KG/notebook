# %%
import gensim
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
model = gensim.models.Word2Vec(sentences, min_count=1)
# Out:
# 2018-08-16 17:23:53,327 : INFO : collecting all words and their counts
# 2018-08-16 17:23:53,341 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-08-16 17:23:53,341 : INFO : collected 3 word types from a corpus of 4 raw words and 2 sentences
# 2018-08-16 17:23:53,344 : INFO : Loading a fresh vocabulary
# 2018-08-16 17:23:53,345 : INFO : min_count=1 retains 3 unique words (100% of original 3, drops 0)
# 2018-08-16 17:23:53,345 : INFO : min_count=1 leaves 4 word corpus (100% of original 4, drops 0)
# 2018-08-16 17:23:53,348 : INFO : deleting the raw counts dictionary of 3 items
# 2018-08-16 17:23:53,350 : INFO : sample=0.001 downsamples 3 most-common words
# 2018-08-16 17:23:53,350 : INFO : downsampling leaves estimated 0 word corpus (5.7% of prior 4)
# 2018-08-16 17:23:53,352 : INFO : estimated required memory for 3 words and 100 dimensions: 3900 bytes
# 2018-08-16 17:23:53,353 : INFO : resetting layer weights
# 2018-08-16 17:23:53,354 : INFO : training model with 3 workers on 3 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-08-16 17:23:53,363 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-16 17:23:53,364 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-16 17:23:53,364 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-16 17:23:53,365 : INFO : EPOCH - 1 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-08-16 17:23:53,368 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-16 17:23:53,369 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-16 17:23:53,370 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-16 17:23:53,370 : INFO : EPOCH - 2 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-08-16 17:23:53,376 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-16 17:23:53,377 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-16 17:23:53,377 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-16 17:23:53,378 : INFO : EPOCH - 3 : training on 4 raw words (1 effective words) took 0.0s, 477 effective words/s
# 2018-08-16 17:23:53,381 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-16 17:23:53,382 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-16 17:23:53,382 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-16 17:23:53,383 : INFO : EPOCH - 4 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-08-16 17:23:53,385 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-16 17:23:53,386 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-16 17:23:53,387 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-16 17:23:53,387 : INFO : EPOCH - 5 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-08-16 17:23:53,388 : INFO : training on a 20 raw words (1 effective words) took 0.0s, 31 effective words/s
# 2018-08-16 17:23:53,389 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model
