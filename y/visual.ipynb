# %%
import matplotlib.pyplot as plt
'''from pylab import *
mpl.rcParams['font.sans-serif']=['qt4agg']'''
import numpy as np 
import pandas as pd 
from pandas import DataFrame as DF
movie=pd.read_csv('/data/data/Movie.txt',sep='\t')

# %%
value = DF(movie)
movie_categories=value['productCountry'].value_counts()

# %%
movie_categories
# Out:
# 美国;                    21116
# 日本;                    10837
# 中国大陆;                   8975
# 英国;                     4767
# 香港;                     4502
# 法国;                     3394
# 韩国;                     1979
# 台湾;                     1675
# 德国;                     1282
# 加拿大;                    1061
# 意大利;                     914
# 西班牙;                     650
# USA;                     621
# Czechoslovakia;          562
# 泰国;                      526
# 中国;                      519
# 苏联;                      494
# 澳大利亚;                    470
# 印度;                      436
# 波兰;                      397
# 英国;美国;                   389
# 俄罗斯;                     366
# UK;                      354
# 美国;加拿大;                  307
# 中国大陆;香港;                 267
# 荷兰;                      248
# 瑞典;                      246
# 美国;英国;                   244
# 西德;                      232
# 法国;意大利;                  230
#                        ...
# 法国;意大利;希腊;德国;              1
# ...

# %%
movie_categories.to_csv('../y/movie_pro.txt')
#plt.pie(movie_categories,labels=movie['categories'])

# %%
movie_cat=pd.read_csv('../y/movie_pro.txt')
#plt.plot(movie['mid'],movie['ratingCount']

# %%
plt.pie(movie_categories,labels=movie_cat['pro'])
plt.title('Top 10 GDP Countries', bbox={'facecolor':'0.8', 'pad':5})
plt.savefig("movie_cat.jpg")
plt.show()
plt.close()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import  matplotlib.font_manager as fm
import matplotlib.pyplot as plt
myfont=fm.FontProperties(fname="C:\Windows\Fonts\simhei.ttf")
plt.rcParams['font.sans-serif']=['SimHei']
import numpy as np
import pandas as pd
from pandas import DataFrame as DF
'''movie=pd.read_csv('Movie.txt',sep='\t')
value = DF(movie)
movie_pro=value['productCountry'].value_counts()
movie_pro.to_csv('movie_pro.csv')'''
movie_pro=pd.read_csv('movie_pro.txt')
plt.pie(movie_pro,labels=movie_pro['pro'])
plt.title('Movie ProductCountry', bbox={'facecolor':'0.8', 'pad':5})
plt.savefig("movie_pro.png")
plt.show()
plt.close()
'''import matplotlib
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])'''
